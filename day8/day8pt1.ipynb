# %%
import numpy as np

# %%
# zero = np.array([1, 1, 1, 0, 1, 1, 1])
one = np.array([0, 0, 1, 0, 0, 1, 0])  # 2
# two = np.array([1, 0, 1, 1, 1, 0, 1])
# three = np.array([1, 0, 1, 1, 0, 1, 1])
four = np.array([0, 1, 1, 1, 0, 1, 0])  # 4
# five = np.array([1, 1, 0, 1, 0, 1, 1])
# six = np.array([1, 1, 0, 1, 1, 1, 1])
seven = np.array([1, 0, 1, 0, 0, 1, 0])  # 3
eight = np.array([1, 1, 1, 1, 1, 1, 1])  # 7
# nine = np.array([1, 1, 1, 1, 0, 1, 1])

# %%
outputs = ["cdgafbe", "cfdg", "cg", "gac",
"de", "bedf", "ecdgf", "ecd",
"abg", "ba", "agfdc", "gab",
"edfabc", "efgab", "cdfg", "ecf",
"cbdgef", "begcaf", "ge", "dbcfe",
"cba", "cab", "bc", "bgce",
"dge", "egd", "fdbeac", "bage",
"cf", "cfgb", "dagec", "bdegf",
"dgbafe", "fcbgae", "adg", "dag",
"geca", "gaf", "gdefacb", "egac",
"fgecbad", "cae", "bfae", "eca",
"eafcb", "agcfb", "gcbfa", "facde",
"cagfdeb", "ce", "gafcbed", "dgcfb",
"agc", "cdebg", "gac", "bdgaf",
"bfegd", "fbc", "fcagdb", "dcefbg",
"degfa", "bdg", "egabd", "gbade",
"ec", "fcgebda", "dbec", "dgbfe",
"edcagb", "cgeafbd", "agcd", "dgca",
"fa", "cegdfb", "bfecg", "ecaf",
"cfeda", "eabd", "gdbcf", "gcedfa",
"afdeb", "febc", "bf", "fb",
"gbecaf", "gafceb", "cbagef", "caedfgb",
"ebdgacf", "cbeadfg", "fdaegcb", "bcgdefa",
"eafdcb", "gbaec", "cgfa", "fcag",
"fabgd", "cda", "gacfed", "dac",
"gcebad", "adgbef", "db", "bd",
"defbcg", "dce", "bfeagdc", "gbacef",
"af", "ebgcfa", "af", "fea",
"af", "afgde", "af", "bcadefg",
"bacdg", "aed", "de", "ade",
"cedb", "bdfegc", "gbdface", "egcbf",
"geacbfd", "cbdgaf", "dgbfac", "cd",
"adcgfbe", "ga", "ag", "cdbafe",
"fb", "bfcdeg", "cdfegb", "bf",
"decg", "bfaedcg", "fbdag", "cbfgd",
"abdcfeg", "de", "abfce", "bgdeacf",
"decg", "ebgfdc", "ed", "gbceaf",
"gfd", "efcd", "gfd", "dcef",
"fead", "bdf", "abefdc", "defa",
"ecadf", "dgcaebf", "gdfabec", "fg",
"bgae", "bdgceaf", "dfcga", "eagb",
"gbeaf", "dfcb", "gbfdec", "adcfgeb",
"ce", "feabgd", "ecgad", "efcg",
"ae", "gea", "acbe", "ceab",
"ade", "aed", "ead", "adefgb",
"cdfbge", "dgce", "cabgef", "ce",
"gbfdc", "gcb", "dcge", "bdcfa",
"cdag", "caf", "caf", "dgac",
"bda", "efbcgad", "cdbg", "gacbe",
"gecba", "ge", "fcgdae", "cdbefag",
"aef", "fea", "edcgbaf", "fcbed",
"cfbgeda", "debfga", "gaecb", "cf",
"cdefagb", "bdg", "fcabgd", "dg",
"cbeagf", "dba", "faecbdg", "ad",
"ecf", "ec", "ec", "efc",
"gbea", "gbf", "gcfdeba", "ageb",
"daebfc", "abgc", "egcdf", "ebc",
"bcedf", "dg", "dg", "abdecfg",
"gfb", "gdfa", "fdacb", "fg",
"eafcb", "bd", "eafdgcb", "bd",
"efbga", "fgca", "cgadefb", "dcbefag",
"gabdcef", "fdage", "agbfec", "dfbe",
"gd", "efdg", "gbefa", "agd",
"bedcfg", "dcbfaeg", "egd", "ged",
"gc", "begfda", "gc", "gedaf",
"abcfge", "fgdeac", "bc", "bcda",
"dbfga", "gcf", "gacbf", "cbegaf",
"eacbgfd", "eadgbf", "dg", "agecbd",
"fbae", "agfbc", "cbgefad", "afgcb",
"faec", "dcegba", "dagceb", "fgdba",
"bced", "bdgcfae", "dgfec", "efabgc",
"abcg", "cbag", "bge", "dacbefg",
"ea", "fgdeab", "afe", "eaf",
"fabcdeg", "aecgd", "gbd", "gb",
"ab", "efdgb", "bgad", "dfebg",
"ef", "aecfg", "ebgf", "gbedafc",
"gcaef", "befagc", "da", "dfbgaec",
"edbg", "begd", "dcbea", "beadcfg",
"cgbad", "dbgfae", "fcbad", "acdefb",
"afed", "bgcaefd", "cgbef", "gafedcb",
"agcbf", "dcgabfe", "fagbdec", "ebda",
"agdfc", "caedgb", "gca", "cg",
"febad", "fgceab", "dfcaeb", "bgf",
"ebgcd", "cbfgead", "bfedgca", "deafbc",
"aed", "ade", "fdgbace", "fgadb",
"bfg", "bcgfd", "dcegabf", "febdac",
"cbagfd", "cfd", "cabfdge", "dcbfga",
"eg", "fbegacd", "edgf", "eg",
"cfba", "dageb", "afebg", "fcagbed",
"abf", "gdabfc", "dbefac", "bafdcg",
"agf", "edfca", "egcdafb", "fag",
"cafg", "fg", "ebfcag", "ebcfg",
"fcedbga", "bdcag", "fb", "aebcgfd",
"gdcfaeb", "dgbecfa", "adfgbc", "bce",
"bg", "bcg", "gbae", "bage",
"eafbd", "gabf", "fgba", "ba",
"dabcgfe", "gcdfba", "gbcade", "acgfbed",
"dg", "adbcfg", "beadfcg", "gbcda",
"aegcb", "fcb", "bcf", "bf",
"cfgba", "gad", "da", "da",
"cgd", "dbefgac", "fdgabce", "agfd",
"fc", "fgc", "cfda", "fdac",
"cbead", "gbfe", "agdcbfe", "ecf",
"dgaefb", "cead", "fecdgba", "bafdec",
"bdfaceg", "fbcdgea", "fb", "bdfegc",
"dcaefbg", "bfga", "gafb", "gfdeab",
"ab", "abdegcf", "ecabgfd", "ba",
"gbfeadc", "aceg", "ag", "egca",
"gcab", "gb", "bfade", "cefbdg",
"afe", "cgeba", "ecdf", "fbeadc",
"cd", "cd", "dabegcf", "ecfgabd",
"ce", "ecd", "adcfb", "gaedb",
"gcfed", "bgfed", "ebdfg", "cdf",
"cafbgde", "gf", "efadcb", "fgbe",
"egacfdb", "ef", "cabfeg", "ef",
"edbag", "fba", "af", "dgabefc",
"cbdag", "ad", "fgbdcae", "dbceg",
"ecg", "ec", "ecfd", "ec",
"dgcbea", "dfcabeg", "gdfeca", "cbdaegf",
"dfeac", "bea", "cebgfa", "ab",
"gfc", "fagceb", "cdfgae", "fcg",
"beafd", "bdg", "dgb", "aefdb",
"bga", "dafge", "agbdefc", "efabgc",
"ac", "fca", "afc", "cdfab"]

# outputs = [
# "fdgacbe", "cefdb", "cefbgd", "gcbe",
# "fcgedb", "cgb", "dgebacf", "gc",
# "cg", "cg", "fdcagb", "cbg",
# "efabcd", "cedba", "gadfec", "cb",
# "gecf", "egdcabf", "bgf", "bfgea",
# "gebdcfa", "ecba", "ca", "fadegcb",
# "cefg", "dcbef", "fcge", "gbcadfe",
# "ed", "bcgafe", "cdgba", "cbgef",
# "gbdfcae", "bgc", "cg", "cgb",
# "fgae", "cfgab", "fg", "bagce"]

# %%
char_map = {
    "a": "0", "b": "0", "c": "0", "d": "0", "e": "0", "f": "0", "g": "0"
}
cts = 0

for digit in outputs:
    
    if len(digit) in [2, 4, 3, 7]:
        cts += 1
cts
# Out:
# 514
